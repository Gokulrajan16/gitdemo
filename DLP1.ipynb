# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulrajan16/gitdemo/blob/main/DLP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fstock.adobe.com%2Fsearch%3Fk%3D%2522powerful%2Bdog%2522&psig=AOvVaw22rQbsBRxXMLduVdQnVJB4&ust=1713526708151000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCKjeg-bWy4UDFQAAAAAdAAAAABAE'
# Out:
# --2024-04-18 13:42:58--  https://www.google.com/url?sa=i&url=https%3A%2F%2Fstock.adobe.com%2Fsearch%3Fk%3D%2522powerful%2Bdog%2522&psig=AOvVaw22rQbsBRxXMLduVdQnVJB4&ust=1713526708151000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCKjeg-bWy4UDFQAAAAAdAAAAABAE
# Resolving www.google.com (www.google.com)... 172.253.63.106, 172.253.63.105, 172.253.63.103, ...
# Connecting to www.google.com (www.google.com)|172.253.63.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘url?sa=i&url=https:%2F%2Fstock.adobe.com%2Fsearch?k=%22powerful+dog%22&psig=AOvVaw22rQbsBRxXMLduVdQnVJB4&ust=1713526708151000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCKjeg-bWy4UDFQAAAAAdAAAAABAE’
#
# url?sa=i&url=https:     [ <=>                ]   1.46K  --.-KB/s    in 0s
#
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/Dog_.jpg')

# %%
print(img.shape)
# Out:
# (900, 1200, 3)

# %%
img=mpimg.imread('/content/Dog_.jpg')
img
# Out:
# array([[[39, 24, 27],
#         [40, 25, 28],
#         [42, 27, 30],
#         ...,
#         [37, 16, 13],
#         [39, 18, 17],
#         [40, 19, 18]],
#
#        [[39, 24, 27],
#         [40, 25, 28],
#         [41, 26, 29],
#         ...,
#         [37, 16, 13],
#         [38, 17, 16],
#         [40, 19, 18]],
#
#        [[40, 25, 28],
#         [40, 25, 28],
#         [40, 25, 28],
#         ...,
#         [36, 15, 12],
#         [37, 16, 15],
#         [38, 17, 16]],
#
#        ...,
#
#        [[43, 23, 25],
#         [44, 24, 26],
#         [44, 25, 27],
#         ...,
#         [21, 34, 43],
#         [20, 33, 42],
#         [19, 32, 41]],
#
#        [[43, 23, 25],
#         [44, 24, 26],
#         [43, 24, 26],
#         ...,
#         [22, 35, 44],
#         [21, 34, 43],
#         [20, 33, 42]],
#
#        [[43, 23, 25],
#         [44, 24, 26],
#         [43, 24, 26],
#         ...,
#         [23, 36, 45],
#         [22, 35, 44],
#         [21, 34, 43]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img)
# Out:
# [[[39 24 27]
#   [40 25 28]
#   [42 27 30]
#   ...
#   [37 16 13]
#   [39 18 17]
#   [40 19 18]]
#
#  [[39 24 27]
#   [40 25 28]
#   [41 26 29]
#   ...
#   [37 16 13]
#   [38 17 16]
#   [40 19 18]]
#
#  [[40 25 28]
#   [40 25 28]
#   [40 25 28]
#   ...
#   [36 15 12]
#   [37 16 15]
#   [38 17 16]]
#
#  ...
#
#  [[43 23 25]
#   [44 24 26]
#   [44 25 27]
#   ...
#   [21 34 43]
#   [20 33 42]
#   [19 32 41]]
#
#  [[43 23 25]
#   [44 24 26]
#   [43 24 26]
#   ...
#   [22 35 44]
#   [21 34 43]
#   [20 33 42]]
#
#  [[43 23 25]
#   [44 24 26]
#   [43 24 26]
#   ...
#   [23 36 45]
#   [22 35 44]
#   [21 34 43]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img=Image.open('/content/Dog_.jpg')
img_resized=img.resize((300,300))

# %%
img_resized.save('dog_resized_img.jpg')

# %%
img_res=mpimg.imread('/content/dog_resized_img.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (300, 300, 3)

# %%
import cv2

# %%
#cv2.imread('/content/dog_resized_img.jpg')

# %%
img=cv2.imread('/content/Dog_.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (900, 1200, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x900>

# %%
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
